# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenminhtien31251023643/NguyenMinhTien.31251023643/blob/main/BAITAPCHUANDOANTIEUDUONG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit pyngrok scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 60.7 MB/s eta 0:00:00
# ...

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier


data = pd.read_csv("/content/diabetes.csv")


X = data.drop("Outcome", axis=1)
y = data["Outcome"]


model = RandomForestClassifier()
model.fit(X, y)


st.set_page_config(
    page_title="Diabetes Prediction",
    page_icon="🩺",
    layout="centered"
)

st.title("🩺 HỆ THỐNG CHẨN ĐOÁN TIỂU ĐƯỜNG")

st.image(
    "https://images.unsplash.com/photo-1576091160399-112ba8d25d1d",
    use_container_width=True
)

st.write("Nhập các chỉ số sức khỏe bên dưới")



st.subheader("📊 Nhập thông số sức khỏe")

preg = st.slider(
    "Pregnancies",
    min_value=0,
    max_value=20,
    value=1
)

glucose = st.slider(
    "Glucose",
    min_value=0,
    max_value=300,
    value=120
)

bp = st.slider(
    "Blood Pressure",
    min_value=0,
    max_value=200,
    value=70
)

skin = st.slider(
    "Skin Thickness",
    min_value=0,
    max_value=100,
    value=20
)

insulin = st.slider(
    "Insulin",
    min_value=0,
    max_value=900,
    value=79
)

bmi = st.slider(
    "BMI",
    min_value=0.0,
    max_value=70.0,
    value=25.0
)

dpf = st.slider(
    "Diabetes Pedigree Function",
    min_value=0.0,
    max_value=3.0,
    value=0.5
)

age = st.slider(
    "Age",
    min_value=1,
    max_value=90,
    value=25
)


if st.button("🔍 Dự đoán"):

    input_data = [[
        preg,
        glucose,
        bp,
        skin,
        insulin,
        bmi,
        dpf,
        age
    ]]

    prediction = model.predict(input_data)

    if prediction[0] == 1:
        st.error("⚠️ Có nguy cơ mắc bệnh tiểu đường")
    else:
        st.success("✅ Không có nguy cơ tiểu đường")


st.markdown("---")

st.subheader("📋 Các chỉ số được sử dụng")

st.write("""
- Pregnancies
- Glucose
- BloodPressure
- SkinThickness
- Insulin
- BMI
- DiabetesPedigreeFunction
- Age
""")
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
from pyngrok import ngrok

# %%
# !ngrok config add-authtoken 3DOHUXO2o3bub9sjrSmkG0WOpM2_2fU3hA5dHQ2gWaAQDzab
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
public_url = ngrok.connect(8501)

print(public_url)
# Out:
# NgrokTunnel: "https://pentagon-gear-facility.ngrok-free.dev" -> "http://localhost:8501"

# %%
import pandas as pd
data=pd.read_csv('/content/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
